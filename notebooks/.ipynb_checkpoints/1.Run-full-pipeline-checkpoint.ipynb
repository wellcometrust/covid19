# %%
# %load_ext autoreload
# %autoreload 2

# To be able to load covid from upper level directory
import sys
sys.path.append("..")

from covid import question_covid, download_scibert
from sklearn.metrics.pairwise import cosine_similarity
from wasabi import msg
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
download_scibert.download_scibert()
# Out:
# ⠙    Downloading Scibert
# Process Process-1:
# Traceback (most recent call last):
#   File "/Users/campea/.pyenv/versions/3.7.6/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/campea/.pyenv/versions/3.7.6/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/campea/covid19/build/virtualenv/lib/python3.7/site-packages/wasabi/printer.py", line 229, in _spinner
#     time.sleep(0.1)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-5846d5f3d821> in <module>
# ----> 1 download_scibert.download_scibert()
#
# ~/covid19/covid/download_scibert.py in download_scibert()
#      12     if not os.path.exists(model_path):
#      13         with msg.loading("   Downloading Scibert"):
# ---> 14             s = requests.get("https://s3-us-west-2.amazonaws.com/ai2-s2-research/"
#      15                              "scibert/huggingface_pytorch/scibert_scivocab_uncased.tar")
#      16         msg.good("Finished")
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     681
#     682         if not stream:
# --> 683             r.content
#     684
#     685         return r
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     562         else:
#     563             while not is_fp_closed(self._fp):
# --> 564                 data = self.read(amt=amt, decode_content=decode_content)
#     565
#     566                 if data:
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/http/client.py in readinto(self, b)
#     499         # connection, and the user is reading more bytes than will be provided
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#     503             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
covid_q = question_covid.train()

# %%
question = "How long can the 2019-nCoV virus remain viable on common surfaces?"

# %%
for answer in covid_q.predict(question):
    print(answer)
# Out:
#  40%|████      | 20/50 [00:30<00:46,  1.55s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-0bd270c0fa75> in <module>
# ----> 1 for answer in covid_q.predict(question):
#       2     print(answer)
#
# ~/covid19/covid/question_covid.py in predict(self, question, n_tf_idf_matches)
#     117             sentences_grouped = ['.'.join(sentences[j:j+n]) for j in range(0, len(sentences), n)]
#     118             from tqdm import tqdm
# --> 119             for subtext in tqdm(sentences_grouped):
#     120                 answer, score = self.get_answer(subtext, question)
#     121                 if score > best_score:
#
# ~/covid19/covid/question_covid.py in get_answer(self, text, question)
#      48         input_text = "[CLS] " + question + " [SEP] " + text + " [SEP]"
#      49         input_ids = self.TOKENIZER.encode(input_text)
# ---> 50         token_type_ids = [0 if i <= input_ids.index(102) else 1 for i in range(len(input_ids))]
#      51         start_scores, end_scores = self.MODEL(torch.tensor([input_ids]), token_type_ids=torch.tensor([token_type_ids]))
#      52         all_tokens = self.TOKENIZER.convert_ids_to_tokens(input_ids)
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions)
#    1492             position_ids=position_ids,
#    1493             head_mask=head_mask,
# -> 1494             inputs_embeds=inputs_embeds,
#    1495         )
#    1496
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask)
#     804             head_mask=head_mask,
#     805             encoder_hidden_states=encoder_hidden_states,
# --> 806             encoder_attention_mask=encoder_extended_attention_mask,
#     807         )
#     808         sequence_output = encoder_outputs[0]
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask)
#     421
#     422             layer_outputs = layer_module(
# --> 423                 hidden_states, attention_mask, head_mask[i], encoder_hidden_states, encoder_attention_mask
#     424             )
#     425             hidden_states = layer_outputs[0]
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask)
#     393             outputs = outputs + cross_attention_outputs[1:]  # add cross attentions if we output attention weights
#     394
# --> 395         intermediate_output = self.intermediate(attention_output)
#     396         layer_output = self.output(intermediate_output, attention_output)
#     397         outputs = (layer_output,) + outputs
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states)
#     346     def forward(self, hidden_states):
#     347         hidden_states = self.dense(hidden_states)
# --> 348         hidden_states = self.intermediate_act_fn(hidden_states)
#     349         return hidden_states
#     350
#
# ~/covid19/build/virtualenv/lib/python3.7/site-packages/transformers/modeling_bert.py in gelu(x)
#     133         Also see https://arxiv.org/abs/1606.08415
#     134     """
# --> 135     return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))
#     136
#     137
#
# KeyboardInterrupt:
